# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("us_monthly_newdeaths.csv")
data
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
plt.subplots(4,1)

plt.show()

# %%
plt.subplots(4,1, figsize = (6,8))
plt.show()

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (6,8))

# %%
fig,ax1
# Out:
# (<Figure size 432x576 with 4 Axes>, <AxesSubplot:>)

# %%
ax1
# Out:
# <AxesSubplot:>

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (6,8))
ax1.plot(data["Month"],data["New_deaths"])

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (8,10))
axes = (ax1,ax2,ax3,ax4)

for i in axes:
    i.plot(data["Month"],data["New_deaths"])

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)
for i in axes:
    i.plot(data["Month"],data["New_deaths"])
    
    i.set_xticklabels([])
    i.set_yticklabels([])

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)
for i in axes:
    i.plot(data["Month"],data["New_deaths"])
    
    i.set_xticklabels([])
    i.set_yticklabels([])
    
    i.tick_params(left = 0, bottom = 0)

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)

for i in axes:
    i.plot(data["Month"],data["New_deaths"])
    i.set_xticklabels([])
    i.set_yticklabels([])
    i.tick_params(left = 0, bottom = 0)
    
    location = ["left","right","top","bottom"]
    for j in location:
        i.spines[j].set_visible(False)

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)

for i in axes:
    i.plot(data["Month"],data["New_deaths"], color = "Green", alpha = 0.4)
    i.set_xticklabels([])
    i.set_yticklabels([])
    i.tick_params(left = 0, bottom = 0)
    
    location = ["left","right","top","bottom"]
    for j in location:
        i.spines[j].set_visible(False)

# %%
data[0:3]
data[3:6]
data[6:9]
data[9:12]
# Out:
#     Month  New_deaths
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)

for i in axes:
    i.plot(data["Month"],data["New_deaths"], color = "Green", alpha = 0.4)
    i.set_xticklabels([])
    i.set_yticklabels([])
    i.tick_params(left = 0, bottom = 0)
    
    location = ["left","right","top","bottom"]
    for j in location:
        i.spines[j].set_visible(False)
        
ax1.plot(data["Month"][0:3],data["New_deaths"][0:3],color = "Green", linewidth = 2.4 )
ax2.plot(data["Month"][2:6],data["New_deaths"][2:6],color = "Green", linewidth = 2.4 )
ax3.plot(data["Month"][5:9],data["New_deaths"][5:9],color = "Green", linewidth = 2.4 )
ax4.plot(data["Month"][8:12],data["New_deaths"][8:12],color = "Green", linewidth = 2.4 )

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)
for i in axes:
    i.plot(data["Month"],data["New_deaths"], color = "Green", alpha = 0.4)
    i.set_xticklabels([])
    i.set_yticklabels([])
    i.tick_params(left = 0, bottom = 0)
    
    location = ["left","right","top","bottom"]
    for j in location:
        i.spines[j].set_visible(False)
        
ax1.plot(data["Month"][0:3],data["New_deaths"][0:3], color = "Green", linewidth = 2.4)
ax2.plot(data["Month"][2:6],data["New_deaths"][2:6], color = "Green", linewidth = 2.4)
ax3.plot(data["Month"][5:9],data["New_deaths"][5:9], color = "Green", linewidth = 2.4)
ax4.plot(data["Month"][8:12],data["New_deaths"][8:12], color = "Green", linewidth = 2.4)

ax1.text(0.5,-80, "0", color = "Purple", weight = "bold")
ax1.text(2.7,300, "77", color = "Purple", weight = "bold")

ax2.text(2.7,300, "77", color = "Purple", weight = "bold")
ax2.text(6,900, "785", color = "Purple", weight = "bold")

ax3.text(6,900, "785", color = "Purple", weight = "bold")
ax3.text(8.8,1000, "739", color = "Purple", weight = "bold")

ax4.text(8.8,1000, "739", color = "Purple", weight = "bold")
ax4.text(12,2500, "2247", color = "Purple", weight = "bold")

ax1.text(1.3,-300, "Jan-Mar", color = "Blue", weight = "bold", size = 12 )
ax2.text(3.7,350, "Apr-Jun", color = "Blue", weight = "bold",size = 14, rotation = 40)
ax3.text(6.8,200, "Jul-Sep", color = "Blue", weight = "bold",size = 14, rotation = 20)
ax4.text(11,600, "Oct-Dec", color = "Blue", weight = "bold" ,size = 14, rotation = 50)
# Out:
# Text(11, 600, 'Oct-Dec')

# %%
data["New_deaths"]
# Out:
# 0        0
# 1        0
# 2       77
# 3     1844
# 4     1448
# 5      785
# 6      769
# 7     1020
# 8      739
# 9      751
# 10    1225
# 11    2247
# Name: New_deaths, dtype: int64

# %%
data["cm"] = data["New_deaths"].cumsum(axis = 0)

# %%
data
# Out:
#     Month  New_deaths     cm
# 0       1           0      0
# 1       2           0      0
# 2       3          77     77
# 3       4        1844   1921
# 4       5        1448   3369
# 5       6         785   4154
# 6       7         769   4923
# 7       8        1020   5943
# 8       9         739   6682
# 9      10         751   7433
# 10     11        1225   8658
# 11     12        2247  10905

# %%
cs = list(data.loc[[2,5,8,11],"cm"])
cs
# Out:
# [77, 4154, 6682, 10905]

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,1, figsize = (10,12))
axes = (ax1,ax2,ax3,ax4)
for i in axes:
    i.plot(data["Month"],data["New_deaths"], color = "Green", alpha = 0.4)
    i.set_xticklabels([])
    i.set_yticklabels([])
    i.tick_params(left = 0, bottom = 0)
    
    location = ["left","right","top","bottom"]
    for j in location:
        i.spines[j].set_visible(False)
        
ax1.plot(data["Month"][0:3],data["New_deaths"][0:3], color = "Green", linewidth = 2.4)
ax2.plot(data["Month"][2:6],data["New_deaths"][2:6], color = "Green", linewidth = 2.4)
ax3.plot(data["Month"][5:9],data["New_deaths"][5:9], color = "Green", linewidth = 2.4)
ax4.plot(data["Month"][8:12],data["New_deaths"][8:12], color = "Green", linewidth = 2.4)

ax1.text(0.5,-80, "0", color = "Purple", weight = "bold")
ax1.text(2.7,300, "77", color = "Purple", weight = "bold")

ax2.text(2.7,300, "77", color = "Purple", weight = "bold")
ax2.text(6,900, "785", color = "Purple", weight = "bold")

ax3.text(6,900, "785", color = "Purple", weight = "bold")
ax3.text(8.8,1000, "739", color = "Purple", weight = "bold")

ax4.text(8.8,1000, "739", color = "Purple", weight = "bold")
ax4.text(12,2500, "2247", color = "Purple", weight = "bold")

ax1.text(1.3,-300, "Jan-Mar", color = "Blue", weight = "bold", size = 12 )
ax2.text(3.7,350, "Apr-Jun", color = "Blue", weight = "bold",size = 14, rotation = 40)
ax3.text(6.8,200, "Jul-Sep", color = "Blue", weight = "bold",size = 14, rotation = 20)
ax4.text(11,600, "Oct-Dec", color = "Blue", weight = "bold" ,size = 14, rotation = 50)

ax1.text(0.5,3300,"The Virus Kills 900 People", color = "Brown", size = 20, weight = "bold")
ax1.text(0.5,2700,"New Deaths in US", color = "Brown", size = 15, weight = "bold")

c = 0
for i in axes:
    i.text(5,1800, "Cummulative Deaths :" + str(cs[c]), color = "Red", weight = "bold", size = 14 )
    c = c+1
